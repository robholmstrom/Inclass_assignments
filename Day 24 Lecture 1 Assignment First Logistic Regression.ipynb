# %% [markdown]
# ## Day 24 Lecture 1 Assignment
#
# In this assignment, we will build our first logistic regression model on numeric data. We will use the FIFA soccer ratings dataset loaded below and analyze the model generated for this dataset.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
def remove_correlated_features(dataset, threshold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if (corr_matrix.iloc[i, j] >= threshold) and (corr_matrix.columns[j] not in col_corr):
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
                if colname in dataset.columns:
                    print(f'Deleted {colname} from dataset.')
                    del dataset[colname]

    return dataset

# %%
soccer_data = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/fifa_ratings.csv')

# %%
soccer_data.head()
# Out:
#        ID               Name  Overall  ...  Marking  StandingTackle  SlidingTackle
# 0  158023           L. Messi       94  ...       33              28             26
# 1   20801  Cristiano Ronaldo       94  ...       28              31             23
# 2  190871          Neymar Jr       92  ...       27              24             33
# 3  192985       K. De Bruyne       91  ...       68              58             51
# 4  183277          E. Hazard       91  ...       34              27             22
#
# [5 rows x 32 columns]

# %% [markdown]
# Our response for our logistic regression model is going to be a binary label, "Elite" or "Not Elite", corresponding to whether or not the player has an overall rating greater than or equal to 75. This corresponds to the top 10% or so of soccer players in the data set. Create the response column.

# %%
soccer_data.corr()
# Out:
#                        ID   Overall  ...  StandingTackle  SlidingTackle
# ID               1.000000 -0.426009  ...       -0.168401      -0.138797
# Overall         -0.426009  1.000000  ...        0.264082       0.224365
# Crossing        -0.277281  0.496603  ...        0.085429       0.078963
# Finishing       -0.169946  0.373079  ...       -0.558565      -0.585841
# HeadingAccuracy -0.288233  0.466908  ...        0.257420       0.234933
# ShortPassing    -0.315288  0.722720  ...        0.235083       0.203009
# Volleys         -0.277298  0.452090  ...       -0.402222      -0.430056
# Dribbling       -0.149494  0.516363  ...       -0.244737      -0.258046
# Curve           -0.307825  0.503054  ...       -0.128246      -0.147523
# FKAccuracy      -0.327434  0.455875  ...       -0.056328      -0.081250
# LongPassing     -0.315755  0.585104  ...        0.384637       0.360727
# BallControl     -0.285933  0.717933  ...       -0.067358      -0.095753
# Acceleration     0.173195  0.150825  ...       -0.295243      -0.276393
# SprintSpeed      0.173248  0.170155  ...       -0.276663      -0.259100
# Agility         -0.036440  0.244344  ...       -0.272831      -0.267649
# Reactions       -0.415952  0.847739  ...        0.248470       0.213073
# Balance          0.035525  0.059425  ...       -0.200966      -0.182409
# ShotPower       -0.327636  0.562960  ...       -0.192883      -0.223037
# Jumping         -0.176311  0.228271  ...        0.179799       0.182095
# Stamina         -0.158896  0.461417  ...        0.302923       0.282724
# Strength        -0.285786  0.341067  ...        0.327302       0.290421
# LongShots       -0.289826  0.502109  ...       -0.275953      -0.308131
# Aggression      -0.354708  0.452916  ...        0.631495       0.606745
# Interceptions   -0.238507  0.333275  ...        0.926279       0.908077
# Positioning     -0.206827  0.438692  ...       -0.386631      -0.409451
# Vision          -0.289062  0.524361  ...       -0.110687      -0.142126
# Penalties       -0.261517  0.391124  ...       -0.404426      -0.429381
# Composure       -0.470480  0.801749  ...        0.171957       0.134281
# Marking         -0.200288  0.305698  ...        0.870861       0.859237
# StandingTackle  -0.168401  0.264082  ...        1.000000       0.966533
# SlidingTackle   -0.138797  0.224365  ...        0.966533       1.000000
#
# [31 rows x 31 columns]

# %%
# answer goes here
response = []
for i in range(soccer_data.shape[0]):
  if soccer_data.Overall[i] >= 75: 
    response.append('Elite') 
  else:
    response.append('Not Elite') 
soccer_data['Response']= response

#remove_correlated_features(soccer_data, 75)

soccer_data.head()
# Out:
#        ID               Name  Overall  ...  StandingTackle  SlidingTackle  Response
# 0  158023           L. Messi       94  ...              28             26     Elite
# 1   20801  Cristiano Ronaldo       94  ...              31             23     Elite
# 2  190871          Neymar Jr       92  ...              24             33     Elite
# 3  192985       K. De Bruyne       91  ...              58             51     Elite
# 4  183277          E. Hazard       91  ...              27             22     Elite
#
# [5 rows x 33 columns]

# %% [markdown]
# Address potential collinearity issues by removing the appropriate features. There is no universally agreed upon technique for doing so, so feel free to use any reasonable method. We have provided the convenience function *remove_correlated_features* at the top as one way of doing so, and we use a threshold of 0.9 for that function to reduce correlation among features.

# %%
# answer goes here
remove_correlated_features(soccer_data, .9)
# Out:
# Deleted StandingTackle from dataset.
# Deleted SlidingTackle from dataset.
#            ID                Name  Overall  ...  Composure  Marking   Response
# 0      158023            L. Messi       94  ...         96       33      Elite
# 1       20801   Cristiano Ronaldo       94  ...         95       28      Elite
# 2      190871           Neymar Jr       92  ...         94       27      Elite
# 3      192985        K. De Bruyne       91  ...         88       68      Elite
# 4      183277           E. Hazard       91  ...         91       34      Elite
# ...       ...                 ...      ...  ...        ...      ...        ...
# 16117  238813        J. Lundstram       47  ...         45       40  Not Elite
# 16118  243165  N. Christoffersson       47  ...         42       22  Not Elite
# 16119  241638           B. Worman       47  ...         41       32  Not Elite
# 16120  246268      D. Walker-Rice       47  ...         46       20  Not Elite
# 16121  246269           G. Nugent       46  ...         43       40  Not Elite
#
# [16122 rows x 31 columns]

# %% [markdown]
# Split the data into train and test, with 80% training and 20% testing. Be sure to leave out columns that would not make sense in the model, like the player ID column.

# %%
# answer goes here
random_test = np.random.randint(0,soccer_data.shape[0], int(0.2*soccer_data.shape[0]))
test_list = random_test.tolist()

test_list.sort()
print(test_list)
print(len(test_list))
test_set = soccer_data.iloc[test_list].drop(['ID', 'Name'], axis = 1)
test_set.head()

training_list = []

# while i < len(test_list):
#   if i not in test_list:
#     training_list.append(i)
# training_list.sort()
# print(training_list)
# print(len(training_list))
    
  
training_set = soccer_data.iloc[training_list].drop(['ID', 'Name'], axis =1)
# Out:
# [5, 7, 8, 10, 14, 40, 47, 58, 58, 63, 64, 73, 85, 86, 90, 93, 98, 104, 108, 127, 128, 130, 133, 137, 143, 144, 147, 148, 160, 163, 165, 166, 172, 174, 175, 178, 185, 186, 199, 200, 211, 213, 219, 221, 232, 232, 235, 246, 250, 258, 266, 281, 284, 287, 291, 297, 301, 304, 309, 312, 318, 324, 324, 325, 338, 364, 364, 366, 369, 382, 385, 393, 397, 399, 404, 408, 
2340, 2348, 2348, 2356, 2362, 2363, 2368, 2371, 2373, 2380, 2392, 2394, 2397, 2399, 2403, 2404, 2405, 2413, 2416, 2426, 2428, 2431, 2431, 2433, 2435, 2436, 2440, 2446, 2450, 2452, 2454, 2454, 2460, 2481, 2486, 2492, 2497, 2498, 2512, 2513, 2515, 2525, 2547, 2554, 2563, 2566, 2568, 2572, 2595, 2595, 2595, 2598, 2600, 2604, 2609, 2614, 2614, 2614, 2618, 2618, 2621, 2627, 2627, 2635, 2636, 2650, 2654, 2654, 2660, 2666, 2683, 2685, 2705, 2712, 2727, 2729, 2733, 2751, 2763, 2764, 2774, 2776, 2782, 2784, 2786, 2788, 2791, 2792, 2796, 2807, 2812, 2813, 2821, 2825, 2826, 2848, 2848, 2855, 2869, 2873, 2874, 2880, 2888, 2888, 2898, 2901, 2908, 2913, 2917, 2930, 2933, 2948, 2948, 2956, 2961, 2964, 2972, 2974, 3000, 3005, 3006, 3020, 3022, 3024, 3029, 3029, 3032, 3035, 3038, 3039, 3047, 3064, 3070, 3077, 3085, 3113, 3121, 3122, 3127, 3141, 3144, 3149, 3151, 3166, 3169, 3170, 3174, 3191, 3193, 3196, 3202, 3204, 3204, 3205, 3210, 3221, 3222, 3223, 3224, 3235, 3236, 3237, 3237, 3244, 3246, 3249, 3249, 3250, 3251, 3253, 3256, 3256, 3263, 3264, 3273, 3282, 3287, 3302, 3311, 3319, 3341, 3341, 3342, 3347, 3350, 3354, 3362, 3371, 3371, 3372, 3374, 3384, 3385, 3385, 3388, 3398, 3398, 3406, 3413, 3416, 3417, 3417, 3439, 3440, 3442, 3443, 3443, 3446, 3460, 3461, 3469, 3472, 3473, 3477, 3486, 3500, 3506, 3511, 3518, 3521, 3530, 3533, 3538, 3547, 3554, 3570, 3573, 3575, 3577, 3579, 3590, 3 ...
# 3224
# []
# 0

# %% [markdown]
# Fit the logistic regression model using the statsmodels package and print out the coefficient summary. Which variables appear to be the most important, and what effect do they have on the probability of a player being elite?

# %%
# answer goes here

# %% [markdown]
# We have yet to discuss how to evaluate the model, which will happen next week, but one intuitive way to see if our model predictions are reasonable is to plot a calibration curve. In essence, the probabilities predicted by a good model will match the observed proportions of outcomes (i.e. If we take all of the predictions around 70% made by our model, the corresponding observed outcomes should be Elite about 70% of the time).
#
# First, make predictions on the test set and join them to the corresponding true outcomes. Then, use the *calibration_curve* function in scikit learn to plot a calibration curve. What do you see?
#
# There is some helpful code for creating calibration plots at the link below:
# https://scikit-learn.org/stable/auto_examples/calibration/plot_calibration_curve.html#sphx-glr-auto-examples-calibration-plot-calibration-curve-py

# %%
# answer goes here

# %% [markdown]
# We see that the lower predicted probabilities tend to be well calibrated - when the model predicts 20% likelihood of eliteness, for example, we tend to see about 20% in reality, which is a good sign. However, the calibration does falter quite a bit for the more confident predictions; weaker calibration at the extremes is fairly common for probabilistic models, although not always to this extent.
